# %% [markdown]
# # _**OPERADORES**_

# %%
x = 15
y = 4

print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x % y)
print(x ** y)
print(x // y)
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 50625
# 3

# %%
x = 12
y = 5

print(x / y)
print(x // y)
# Out:
# 2.4
# 2

# %%
numbers = [1, 2, 3, 4, 5]

count = len(numbers)      # 1º: calculas y guardas
if count > 3:              # 2º: usas la variable
    print(f"List has {count} elements")

numbers = [1, 2, 3, 4, 5]

if (count := len(numbers)) > 3: # Walrus operator permite asignar el valor a una variable y usarlo inmediatamente
    print(f"List has {count} elements")
# Out:
# List has 5 elements
# List has 5 elements

# %%
# Forma normal

edad = 20

if edad >= 18:
    estado = "mayor de edad"
else:
    estado = "menor de edad"
print(estado)   # mayor de edad

num = 6
x = "WEEKEND!" if num > 5 else "Workday" # Ternary operation, forma compacta para if/else 
print(x)

y = "mayor de edad" if edad > 25 else "menor de edad"
print(y)
# Out:
# mayor de edad
# WEEKEND!
# menor de edad

# %%
# Instead of elifs

num = 3
x = "Fri" if num == 5 else "Sat" if num == 6 else "Sun" if num == 7 else "weekday"
print(x)

dia = 38
sem = 'No existe el día 0' if dia == 0 else \
'Semana 1' if dia > 1 and dia < 8 else \
"Semana 2" if dia > 7 and dia < 15 else \
"Semana 3" if dia > 14 and dia < 22 else \
"Semana 4" if dia > 21 and dia < 32 else \
"Eso no es un día del mes"

print(sem)
# Out:
# weekday
# Eso no es un día del mes

# %%
# Operadores de comparación

x = 5
y = 3

print(x == y)
print(x != y)
print(x > y)
print(x < y)
print(x >= y)
print(x <= y)
# Out:
# False
# True
# True
# False
# True
# False

# %%
x = 5
print(x > 0 and x < 10)
print(x < 5 or x < 10)
print(not(x > 3 and x < 10)) # Not true = False, de dentro hacia fuera
# Out:
# True
# True
# False

# %%
x = ["apple", "banana"]
y = ["apple", "banana"]
z = x

print(x is z)
print(x is y) # is compara si son el mismo objeto en memoria
print(x == y) # == compara si el contenido/valor es igual
# Out:
# True
# False
# True

# %%
x = ["apple", "banana"]
y = ["apple", "banana"]

print(x is not y)
print(x != y)
# Out:
# True
# False

# %%
fruits = ["apple", "banana", "cherry"]
print("banana" in fruits)
print("pineapple" not in fruits)
# Out:
# True
# True

# %%
text = "Hello World"

print("H" in text); print("hello" in text); print("z" not in text); print('World ' in text)
# Out:
# True
# False
# True
# False

# %% [markdown]
# # _**PYTHON LISTS**_
#
# Python Collections (Arrays)
#
# There are four collection data types in the Python programming language:
#
# - List is a collection which is ordered and changeable. Allows duplicate members.
# - Tuple is a collection which is ordered and unchangeable. Allows duplicate members.
# - Set is a collection which is unordered, unchangeable*, and unindexed. No duplicate members.
# - Dictionary is a collection which is ordered** and changeable. No duplicate members.

# %%
thislist = ["apple", "banana", "cherry", "cherry"] 
print(thislist)
print(len(thislist))

# Allow duplicates
# Puede contener diferentes tipos de datos dentro:
list1 = ["abc", 34, True, 40, "male"]
print(list1); print(type(list1))

thislist1 = list(("apple", "banana", "cherry")) # note the double round-brackets
print(thislist1)
print(thislist[1])
print(thislist[-3])
# Out:
# ['apple', 'banana', 'cherry', 'cherry']
# 4
# ['abc', 34, True, 40, 'male']
# <class 'list'>
# ['apple', 'banana', 'cherry']
# banana
# banana

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[2:5])
print(thislist[:4])
print(thislist[2:])
# Out:
# ['cherry', 'orange', 'kiwi']
# ['apple', 'banana', 'cherry', 'orange']
# ['cherry', 'orange', 'kiwi', 'melon', 'mango']

# %%
thislist = ["apple", "banana", "cherry"]
if "apple" in thislist:
  print("Yes, 'apple' is in the fruits list")
# Out:
# Yes, 'apple' is in the fruits list

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1] = "blackcurrant"
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'cherry']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[1:3] = ["blackcurrant", "watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'orange', 'kiwi', 'mango']

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1:2] = ["blackcurrant", "watermelon"] # Change the second value by replacing it with two new values:
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1:3] = ["watermelon"] # Change the second and third value by replacing it with one value:
print(thislist)
# Out:
# ['apple', 'watermelon']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.insert(1, "watermelon")
thislist.append("orange")
print(thislist)
# Out:
# ['apple', 'watermelon', 'banana', 'cherry', 'orange']

# %%
thislist = ["apple", "banana", "cherry"]
tropical = ["mango", "pineapple", "papaya"]
thislist.extend(tropical) # Add the elements of tropical to thislist:
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']

# %%
thislist = ["apple", "banana", 'banana', "cherry"]
thistuple = ("kiwi", "orange")
thislist.extend(thistuple) # Add elements of a tuple to a list
thislist.remove("banana") # Si hay mas de 1 banana, solo elimina el primero 
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'kiwi', 'orange']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.pop(2) # removes the specified index, if not specified, removes the last item
del thislist[0]
print(thislist)
del thislist # elimina la lista completa
# Out:
# ['banana']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.clear()
print(thislist)
# Out:
# []

# %%
thislist = ["apple", "banana", "cherry"]
for i in range(len(thislist)):
  print(thislist[i]) # Print all items by referring to their index number:
# Out:
# apple
# banana
# cherry

# %%
thislist = ["apple", "banana", "cherry"]
i = 0 # Variable i iniciada en 0
while i < len(thislist): # Mientras i < 3, sigue en el bucle, cuando llegue a 3, paras. 
  print(thislist[i])
  i = i + 1
# Out:
# apple
# banana
# cherry

# %%
thislist = ["apple", "banana", "cherry"]
[print(x) for x in thislist]
# Out:
# apple
# banana
# cherry
# [None, None, None]

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = []

for x in fruits:
  if "a" in x:
    newlist.append(x)

print(newlist)

# Lo mismo pero con comprehension: 
# newlist = [expression for item in iterable if condition == True]


fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = [x for x in fruits if "a" in x]
print(newlist)

newlist1 = [x for x in fruits if x != "apple"]
print(newlist1)
# Out:
# ['apple', 'banana', 'mango']
# ['apple', 'banana', 'mango']
# ['banana', 'cherry', 'kiwi', 'mango']

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist1 = [100, 50, 65, 82, 23]

thislist.sort()
thislist1.sort(reverse=True)
print(thislist); print(thislist1)
# Out:
# ['banana', 'kiwi', 'mango', 'orange', 'pineapple']
# [100, 82, 65, 50, 23]

# %%
# Customize Sort Function
# Sort the list based on how close the number is to 50:

def myfunc(n):
  return abs(n - 50)

thislist = [100, 50, 65, 82, 23]
thislist.sort(key = myfunc)
print(thislist)
# Out:
# [50, 65, 23, 82, 100]

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.sort() # By default the sort() method is case sensitive, resulting in all capital letters being sorted before lower case letters
print(thislist)
# Out:
# ['Kiwi', 'Orange', 'banana', 'cherry']

# %%
# Perform a case-insensitive sort of the list:
# So if you want a case-insensitive sort function, use str.lower as a key function:
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.sort(key = str.lower)
print(thislist)
# Out:
# ['banana', 'cherry', 'Kiwi', 'Orange']

# %%
# Reverse the order of the list items:

thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.reverse()
print(thislist)
# Out:
# ['cherry', 'Kiwi', 'Orange', 'banana']
# ['cherry', 'Kiwi', 'Orange', 'banana']

# %%
# Métodos para copiar listas

thislist = ["apple", "banana", "cherry"]
mylist = thislist.copy()
print(mylist)

thislist = ["apple", "banana", "cherry"]
mylist = list(thislist)
print(mylist)

thislist = ["apple", "banana", "cherry"]
mylist = thislist[:]
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry']

# %%
# Join lists

list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)

# Append list2 into list1:

list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

for x in list2:
  list1.append(x)

print(list1)

# Use the extend() method to add list2 at the end of list1:

list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

list1.extend(list2)
print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]
# ['a', 'b', 'c', 1, 2, 3]
# ['a', 'b', 'c', 1, 2, 3]
