# %% [markdown]
# # _**TUPLES AND SETS**_
#
# ## _**TUPLES**_

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple)

thistuple1 = "apple", "banana", "cherry"
print(thistuple1)
# Out:
# ('apple', 'banana', 'cherry')
# ('apple', 'banana', 'cherry')
